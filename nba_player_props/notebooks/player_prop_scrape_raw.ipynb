# %%
import os, csv, time, requests
from datetime import datetime, timedelta, timezone

API_KEY  = os.getenv("ODDS_API_KEY") or "340d84031bd365136b8dece4bc4b387e"
SPORT    = "basketball_nba"
REGION   = "us"
ODDS_FMT = "american"
DATE_FMT = "%Y-%m-%d"

# --- SMALL TEST WINDOW (adjust as needed) ---
START_DATE = "2024-01-03"   # day after your last scraped game
END_DATE   = "2024-04-14"   # regular season end

# Snapshot timing (how long before tip to pull history)
SNAP_BEFORE_MIN = 60

# NBA player prop market keys per docs
NBA_PROP_MARKETS = [
    "player_points","player_rebounds","player_assists","player_threes",
    "player_turnovers",
]

BASE = "https://api.the-odds-api.com/v4"

# --- Request/row counters ---
REQ_COUNT = 0
ROW_COUNT = 0

def get(url, params, retries=3, sleep_s=1.0):
    global REQ_COUNT
    for i in range(retries):
        r = requests.get(url, params=params, timeout=30)
        if r.status_code == 429:
            # rate limited: back off
            time.sleep(5 + i * 5)
            continue
        if r.ok:
            REQ_COUNT += 1
            return r.json(), r.headers
        # transient errors
        time.sleep(sleep_s * (i + 1))
    r.raise_for_status()

def historical_events_for_day(day_iso: str):
    """
    List historical events (game IDs) on this day (UTC snapshot at noon).
    Endpoint: /historical/sports/{sport}/events
    """
    date_ts = f"{day_iso}T12:00:00Z"
    url = f"{BASE}/historical/sports/{SPORT}/events"
    params = {"apiKey": API_KEY, "date": date_ts}
    data, _ = get(url, params)
    return data.get("data", []) if isinstance(data, dict) else []

def historical_event_props(event_id: str, snapshot_iso: str):
    """
    Get draftkings-only player prop odds for a single event at snapshot time.
    Endpoint: /historical/sports/{sport}/events/{eventId}/odds
    """
    url = f"{BASE}/historical/sports/{SPORT}/events/{event_id}/odds"
    params = {
        "apiKey": API_KEY,
        "regions": REGION,
        "oddsFormat": ODDS_FMT,
        "date": snapshot_iso,
        "markets": ",".join(NBA_PROP_MARKETS),
        "bookmakers": "draftkings",  # <<< draftkings-only
    }
    data, _ = get(url, params)
    return data.get("data", {}) if isinstance(data, dict) else {}

def choose_snapshot(commence_iso: str, minutes_before: int = 60) -> str:
    tip = datetime.fromisoformat(commence_iso.replace("Z","+00:00"))
    snap = tip - timedelta(minutes=minutes_before)
    return snap.replace(tzinfo=timezone.utc).isoformat().replace("+00:00","Z")

out_path = "nba_player_props_draftkings_sample.csv"
fieldnames = [
    "event_id","commence_time","home_team","away_team",
    "bookmaker","market_key","participant","outcome_name","price","point"
]

file_exists = os.path.isfile(out_path)

# Fresh file each run
with open(out_path, "a", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()

    cur = datetime.fromisoformat(START_DATE).date()
    end = datetime.fromisoformat(END_DATE).date()

    while cur <= end:
        day_iso = cur.strftime(DATE_FMT)
        day_rows = 0
        try:
            events = historical_events_for_day(day_iso)
        except Exception as e:
            print(f"[{day_iso}] events error: {e}")
            cur += timedelta(days=1)
            continue

        for ev in events:
            try:
                event_id = ev["id"]
                commence = ev["commence_time"]
                home = ev.get("home_team")
                away = ev.get("away_team")
                snap_iso = choose_snapshot(commence, SNAP_BEFORE_MIN)

                ev_data = historical_event_props(event_id, snap_iso)
                if not ev_data:
                    continue

                bookmakers = ev_data.get("bookmakers", [])
                for bk in bookmakers:
                    bk_name = bk.get("key")
                    if bk_name != "draftkings":
                        continue  # defensive: keep only draftkings
                    for m in bk.get("markets", []):
                        mkey = m.get("key")
                        if mkey not in NBA_PROP_MARKETS:
                            continue
                        for oc in m.get("outcomes", []):
                            row = {
                                "event_id": event_id,
                                "commence_time": commence,
                                "home_team": home,
                                "away_team": away,
                                "bookmaker": bk_name,
                                "market_key": mkey,
                                "participant": oc.get("name"),
                                "outcome_name": oc.get("description") or oc.get("name"),
                                "price": oc.get("price"),
                                "point": oc.get("point"),
                            }
                            writer.writerow(row)
                            ROW_COUNT += 1
                            day_rows += 1

                time.sleep(0.2)  # be polite
            except Exception as e:
                print(f"[{day_iso}] event {ev.get('id')} error: {e}")
                continue

        print(f"Done {day_iso} | events: {len(events)} | draftkings prop rows: {day_rows}")
        time.sleep(0.25)
        cur += timedelta(days=1)

print(f"\nRequests used: {REQ_COUNT} | Rows written: {ROW_COUNT} → {out_path}")
# Out:
# Done 2024-01-03 | events: 12 | draftkings prop rows: 1219
# Done 2024-01-04 | events: 2 | draftkings prop rows: 252
# Done 2024-01-05 | events: 14 | draftkings prop rows: 1346
# Done 2024-01-06 | events: 4 | draftkings prop rows: 392
# Done 2024-01-07 | events: 9 | draftkings prop rows: 840
# Done 2024-01-08 | events: 6 | draftkings prop rows: 650
# Done 2024-01-09 | events: 5 | draftkings prop rows: 522
# Done 2024-01-10 | events: 10 | draftkings prop rows: 1012
# Done 2024-01-11 | events: 5 | draftkings prop rows: 548
# Done 2024-01-12 | events: 10 | draftkings prop rows: 1108
# Done 2024-01-13 | events: 8 | draftkings prop rows: 830
# Done 2024-01-14 | events: 5 | draftkings prop rows: 280
# Done 2024-01-15 | events: 11 | draftkings prop rows: 1084
# Done 2024-01-16 | events: 3 | draftkings prop rows: 372
# [2024-01-17] event 36e7461f05a993188963028c3eef01ec error: 404 Client Error: Not Found for url: https://api.the-odds-api.com/v4/historical/sports/basketball_nba/events/36e7461f05a993188963028c3eef01ec/odds?apiKey=340d84031bd365136b8dece4bc4b387e&regions=us&oddsFormat=american&date=2024-01-18T01%3A10%3A00Z&markets=player_points%2Cplayer_rebounds%2Cplayer_assists%2Cplayer_threes%2Cplayer_turnovers&bookmakers=draftkings
# Done 2024-01-17 | events: 10 | draftkings prop rows: 907
# Done 2024-01-18 | events: 5 | draftkings prop rows: 522
# Done 2024-01-19 | events: 7 | draftkings prop rows: 800
# Done 2024-01-20 | events: 8 | draftkings prop rows: 810
# Done 2024-01-21 | events: 6 | draftkings prop rows: 563
# Done 2024-01-22 | events: 8 | draftkings prop rows: 852
# Done 2024-01-23 | events: 5 | draftkings prop rows: 626
# Done 2024-01-24 | events: 8 | draftkings prop rows: 732
# Done 2024-01-25 | events: 7 | draftkings prop rows: 814
# Done 2024-01-26 | events: 8 | draftkings prop rows: 840
# Done 2024-01-27 | events: 10 | draftkings prop rows: 987
# Done 2024-01-28 | events: 5 | draftkings prop rows: 414
# Done 2024-01-29 | events: 12 | draftkings prop rows: 1404
# Done 2024-01-30 | events: 5 | draftkings prop rows: 494
# Done 2024-01-31 | events: 10 | draftkings prop rows: 1063
# Done 2024-02-01 | events: 4 | draftkings prop rows: 452
# Done 2024-02-02 | events: 10 | draftkings prop rows: 1084
# Done 2024-02-03 | events: 6 | draftkings prop rows: 628
# Done 2024-02-04 | events: 9 | draftkings prop rows: 859
# Done 2024-02-05 | events: 6 | draftkings prop rows: 560
# Done 2024-02-06 | events: 7 | draftkings prop rows: 626
# Done 2024-02-07 | events: 7 | draftkings prop rows: 677
# Done 2024-02-08 | events: 9 | draftkings prop rows: 736
# Done 2024-02-09 | events: 6 | draftkings prop rows: 503
# Done 2024-02-10 | events: 11 | draftkings prop rows: 1116
# Done 2024-02-11 | events: 2 | draftkings prop rows: 248
# Done 2024-02-12 | events: 10 | draftkings prop rows: 1155
# Done 2024-02-13 | events: 6 | draftkings prop rows: 677
# Done 2024-02-14 | events: 13 | draftkings prop rows: 1403
# Done 2024-02-15 | events: 3 | draftkings prop rows: 336
# Done 2024-02-16 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-17 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-18 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-19 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-20 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-21 | events: 12 | draftkings prop rows: 1510
# Done 2024-02-22 | events: 12 | draftkings prop rows: 1511
# Done 2024-02-23 | events: 10 | draftkings prop rows: 1101
# Done 2024-02-24 | events: 3 | draftkings prop rows: 345
# Done 2024-02-25 | events: 11 | draftkings prop rows: 1330
# Done 2024-02-26 | events: 4 | draftkings prop rows: 480
# Done 2024-02-27 | events: 11 | draftkings prop rows: 1338
# Done 2024-02-28 | events: 6 | draftkings prop rows: 646
# Done 2024-02-29 | events: 8 | draftkings prop rows: 982
# Done 2024-03-01 | events: 9 | draftkings prop rows: 896
# Done 2024-03-02 | events: 5 | draftkings prop rows: 548
# Done 2024-03-03 | events: 8 | draftkings prop rows: 858
# Done 2024-03-04 | events: 6 | draftkings prop rows: 597
# Done 2024-03-05 | events: 9 | draftkings prop rows: 998
# Done 2024-03-06 | events: 8 | draftkings prop rows: 781
# Done 2024-03-07 | events: 7 | draftkings prop rows: 831
# Done 2024-03-08 | events: 8 | draftkings prop rows: 722
# Done 2024-03-09 | events: 7 | draftkings prop rows: 802
# Done 2024-03-10 | events: 9 | draftkings prop rows: 976
# Done 2024-03-11 | events: 6 | draftkings prop rows: 632
# Done 2024-03-12 | events: 7 | draftkings prop rows: 690
# Done 2024-03-13 | events: 9 | draftkings prop rows: 864
# Done 2024-03-14 | events: 6 | draftkings prop rows: 682
# Done 2024-03-15 | events: 6 | draftkings prop rows: 746
# Done 2024-03-16 | events: 9 | draftkings prop rows: 878
# Done 2024-03-17 | events: 7 | draftkings prop rows: 722
# Done 2024-03-18 | events: 8 | draftkings prop rows: 778
# Done 2024-03-19 | events: 5 | draftkings prop rows: 624
# Done 2024-03-20 | events: 8 | draftkings prop rows: 702
# Done 2024-03-21 | events: 7 | draftkings prop rows: 755
# Done 2024-03-22 | events: 8 | draftkings prop rows: 877
# Done 2024-03-23 | events: 8 | draftkings prop rows: 884
# Done 2024-03-24 | events: 6 | draftkings prop rows: 650
# Done 2024-03-25 | events: 11 | draftkings prop rows: 1020
# Done 2024-03-26 | events: 4 | draftkings prop rows: 487
# Done 2024-03-27 | events: 12 | draftkings prop rows: 1066
# Done 2024-03-28 | events: 2 | draftkings prop rows: 262
# Done 2024-03-29 | events: 12 | draftkings prop rows: 1380
# Done 2024-03-30 | events: 3 | draftkings prop rows: 358
# Done 2024-03-31 | events: 10 | draftkings prop rows: 976
# Done 2024-04-01 | events: 6 | draftkings prop rows: 607
# Done 2024-04-02 | events: 9 | draftkings prop rows: 1038
# Done 2024-04-03 | events: 9 | draftkings prop rows: 865
# Done 2024-04-04 | events: 5 | draftkings prop rows: 596
# Done 2024-04-05 | events: 12 | draftkings prop rows: 1159
# Done 2024-04-06 | events: 4 | draftkings prop rows: 368
# Done 2024-04-07 | events: 13 | draftkings prop rows: 1426
# Done 2024-04-08 | events: 14 | draftkings prop rows: 1370
# Done 2024-04-09 | events: 14 | draftkings prop rows: 1370
# Done 2024-04-10 | events: 8 | draftkings prop rows: 737
# Done 2024-04-11 | events: 5 | draftkings prop rows: 536
# [2024-04-12] event 04a429162cbac45dfe05de7e503ceeb6 error: 404 Client Error: Not Found for url: https://api.the-odds-api.com/v4/historical/sports/basketball_nba/events/04a429162cbac45dfe05de7e503ceeb6/odds?apiKey=340d84031bd365136b8dece4bc4b387e&regions=us&oddsFormat=american&date=2024-04-16T22%3A10%3A00Z&markets=player_points%2Cplayer_rebounds%2Cplayer_assists%2Cplayer_threes%2Cplayer_turnovers&bookmakers=draftkings
# Done 2024-04-12 | events: 16 | draftkings prop rows: 1188
# Done 2024-04-13 | events: 8 | draftkings prop rows: 678
# [2024-04-14] event 04a429162cbac45dfe05de7e503ceeb6 error: 404 Client Error: Not Found for url: https://api.the-odds-api.com/v4/historical/sports/basketball_nba/events/04a429162cbac45dfe05de7e503ceeb6/odds?apiKey=340d84031bd365136b8dece4bc4b387e&regions=us&oddsFormat=american&date=2024-04-16T22%3A00%3A00Z&markets=player_points%2Cplayer_rebounds%2Cplayer_assists%2Cplayer_threes%2Cplayer_turnovers&bookmakers=draftkings
# Done 2024-04-14 | events: 17 | draftkings prop rows: 1076
#
# Requests used: 934 | Rows written: 87192 → nba_player_props_draftkings_sample.csv
